# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('output/wikimedia_events_combined.csv')
df
# Out:
#       timestamp    bot  minor            user                 domain  \
# 0    1726189154   True  False          Cewbot       www.wikidata.org
# 1    1726189153   True  False          Cewbot       zh.wikipedia.org
# 2    1726189153  False  False   Sotho Tal Ker       www.wikidata.org
# 3    1726189153  False  False     Quesotiotyo       www.wikidata.org
# 4    1726189151  False    NaN        Hypnosef       en.wikipedia.org
# ..          ...    ...    ...             ...                    ...
# 330  1726189163  False    NaN  Smasongarrison       en.wikipedia.org
# 331  1726189165   True   True  JJMC89 bot III       en.wikipedia.org
# 332  1726189169  False  False     Quesotiotyo       www.wikidata.org
# 333  1726189166  False  False       Peshigome       fr.wikipedia.org
# 334  1726189167   True    NaN       BadzilBot  commons.wikimedia.org
#
#      old_length  new_length  length_diff  length_diff_percent
# 0      108563.0    109947.0       1384.0             1.274836
# 1       27285.0     27283.0         -2.0            -0.007330
# 2       26350.0     26696.0        346.0             1.313093
# 3        6718.0      7070.0        352.0             5.239655
# 4           NaN         NaN          NaN                  NaN
# ..          ...         ...          ...                  ...
# 330         NaN         NaN          NaN                  NaN
# 331     14568.0     14568.0          0.0             0.000000
# 332      6366.0      6718.0        352.0             5.529375
# 333     43151.0     43820.0        669.0             1.550370
# 334         NaN         NaN          NaN                  NaN
#
# [335 rows x 9 columns]
